# %%
from pathlib import Path
import pandas as pd


files = sorted(Path(".").glob("2025-0*.csv"))


if not files:
    print("No files matched pattern: 2025-0*.csv")
else:
    summary_rows = []

    for file in files:
        df = pd.read_csv(file)
        missing_per_col = df.isna().sum()
        total_missing = int(missing_per_col.sum())
        rows_with_missing = int(df.isna().any(axis=1).sum())

        print(f"\n{file.name}")
        print("-" * len(file.name))
        print(f"Total missing values: {total_missing}")
        print(f"Rows with at least one missing value: {rows_with_missing}")

        if total_missing > 0:
            print("Missing values by column:")
            print(missing_per_col[missing_per_col > 0].sort_values(ascending=False).to_string())

            # ── NEW: show line numbers ──────────────────────────────────────
            print("\nLines with missing values:")
            missing_mask = df.isna().any(axis=1)
            for idx, row in df[missing_mask].iterrows():
                line_num = idx + 2  # +1 for 0-based index, +1 for header row
                missing_cols = row.index[row.isna()].tolist()
                print(f"  Line {line_num}: {', '.join(missing_cols)}")
            # ──────────────────────────────────────────────────────────────
        else:
            print("No missing data found.")

        summary_rows.append(
            {
                "file": file.name,
                "total_missing_values": total_missing,
                "rows_with_missing": rows_with_missing,
            }
        )

    summary_df = pd.DataFrame(summary_rows).sort_values("file")
    print("\nSummary across files:")
    print(summary_df.to_string(index=False))
# Out:
# 2025-04.csv
# -----------
# Total missing values: 5
# Rows with at least one missing value: 5
# Missing values by column:
# HTRK_VEN01_TI01     4
# HTR9_VES01_TUD01    1
#
# Lines with missing values:
#   Line 703: HTRK_VEN01_TI01
#   Line 704: HTRK_VEN01_TI01
#   Line 705: HTRK_VEN01_TI01
#   Line 706: HTRK_VEN01_TI01
#   Line 2053: HTR9_VES01_TUD01
#
# 2025-05.csv
# -----------
# Total missing values: 1
# Rows with at least one missing value: 1
# Missing values by column:
# HTR9_VES01_TUD01    1
#
# Lines with missing values:
#   Line 1285: HTR9_VES01_TUD01
#
# 2025-06.csv
# -----------
# Total missing values: 20
# Rows with at least one missing value: 2
# Missing values by column:
# R01_07_CO201        2
# R01_07_FCI01        2
# R01_07_TRU01        2
# HTR9_VES01_AZ01     2
# HTR9_VES01_SI01     2
# HTR9_VES01_SV01     2
# HTR9_VES01_TUD01    2
# HTRK_VEN01_TI01     2
# R01_06_TRU01        2
# R01_08_TRU01        2
#
# Lines with missing values:
#   Line 2533: R01_07_CO201, R01_07_FCI01, R01_07_TRU01, HTR9_VES01_AZ01, HTR9_VES01_SI01, HTR9_VES01_SV01, HTR9_VES01_TUD01, HTRK_VEN01_TI01, R01_06_TRU01, R01_08_TRU01
#   Line 2534: R01_07_CO201, R01_07_FCI01, R01_07_TRU01, HTR9_VES01_AZ01, HTR9_VES01_SI01, HTR9_VES01_SV01, HTR9_VES01_TUD01, HTRK_VEN01_TI01, R01_06_TRU01, R01_08_TRU01
#
# 2025-07.csv
# -----------
# Total missing values: 0
# Rows with at least one missing value: 0
# No missing data found.
#
# 2025-08.csv
# -----------
# Total missing values: 0
# Rows with at least one missing value: 0
# No missing data found.
#
# 2025-09.csv
# -----------
# Total missing values: 0
# Rows with at least one missing value: 0
# No missing data found.
#
# Summary across files:
#        file  total_missing_values  rows_with_missing
# 2025-04.csv                     5                  5
# 2025-05.csv                     1                  1
# 2025-06.csv                    20                  2
# 2025-07.csv                     0                  0
# 2025-08.csv                     0                  0
# 2025-09.csv                     0                  0
